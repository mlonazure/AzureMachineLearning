# %%
import azureml.core
from azureml.core import Workspace, Datastore, Dataset

mlonazure_ws = Workspace.from_config()

mlonazure_ds = mlonazure_ws.get_default_datastore()

print('Workspace Name: ' + mlonazure_ws.name, 
      'Resource Group: ' + mlonazure_ws.resource_group,
      'Default Storage Account Name: ' + mlonazure_ds.account_name,
      'AzureML Core Version: ' + azureml.core.VERSION,
      sep = '\n')
# Out:
# Workspace Name: mlonazure-ws
# Resource Group: mlonazure-rg
# Default Storage Account Name: mlonazurews7669880942
# AzureML Core Version: 1.8.0

# %%
from azureml.core.compute import AmlCompute

compute_target = AmlCompute(mlonazure_ws, 'amlcluster2c-4gb')

print('Compute Name:', compute_target.name)
# Out:
# Compute Name: amlcluster2c-4gb

# %% [raw]
# from azureml.core.runconfig import RunConfiguration
# from azureml.core.conda_dependencies import CondaDependencies
#
# # create a new RunConfig object
# conda_run_config = RunConfiguration(framework="python")
#
# conda_run_config.environment.docker.enabled = True
# conda_run_config.environment.docker.base_image = azureml.core.runconfig.DEFAULT_CPU_IMAGE
#
# cd = CondaDependencies.create(pip_packages=['azureml-sdk[automl]'],
#                               conda_packages=['numpy', 'py-xgboost<=0.80'])
# conda_run_config.environment.python.conda_dependencies = cd
#
# print('run config is ready')

# %%
#Note that you need to run ../00. Get Data from OpenDatasets.ipynb to get and register this dataset.
datasetName_train = 'OJSales_Train_Subset'
datasetName_validate = 'OJSales_Validate_Subset'

data_train_ds = Dataset.get_by_name(mlonazure_ws,datasetName_train,version='latest')
data_validate_ds = Dataset.get_by_name(mlonazure_ws,datasetName_validate,version='latest')

# %%
from azureml.core.workspace import Workspace
from azureml.core.experiment import Experiment
from azureml.train.automl import AutoMLConfig

import logging

target_column_name = 'Quantity'
dateColumn = 'WeekStarting'

training_data = data_train_ds

automl_config = AutoMLConfig(task='forecasting',
                             path = './project',
                             debug_log='automl_debuglog.log',
                             primary_metric='r2_score',
                             iteration_timeout_minutes = 120,
                             experiment_timeout_hours=10,
                             featurization='auto',
                             max_concurrent_iterations=20, #100 is the max but its one per node so max should be set to the max nodes.
                             max_cores_per_iteration=-1,
                             enable_dnn=False,
                             enable_early_stopping=True,
                             n_cross_validations=3,
                             verbosity = logging.INFO,                             
                             compute_target=compute_target,
                             training_data=training_data,
                             label_column_name=target_column_name,
                             time_column_name = dateColumn,
                             max_horizon = 6,
                             grain_column_names = ['Store', 'Brand'],
                             #drop_column_names = ['',''],
                             model_explainability=True)

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput, PipelineDataset
from azureml.pipeline.steps import AutoMLStep

metrics_data = PipelineData(name='metrics_data',
                           datastore=mlonazure_ds,
                           pipeline_output_name='metrics_output_name',
                           training_output=TrainingOutput(type='Metrics'))

model_data_bestmodel = PipelineData(name='model_data_bestmodel',
                           datastore=mlonazure_ds,
                           pipeline_output_name='best_model_output_name',
                           training_output=TrainingOutput(type='Model'))

model_data_normalizedrmse = PipelineData(name='model_data_normalizedrmse',
                           datastore=mlonazure_ds,
                           pipeline_output_name='nrmse_model_output_name',
                           training_output=TrainingOutput(type='Model',metric='normalized_root_mean_squared_error'))

automl_step = AutoMLStep(name='TrainOJSalesData_AutoML',
                        automl_config=automl_config,
                        inputs=None,
                        outputs=[metrics_data, model_data_bestmodel,model_data_normalizedrmse],
                        allow_reuse=False,
                        version=None,
                        passthru_automl_config=True)

# %%
from azureml.pipeline.core import Pipeline
from azureml.pipeline.steps import PythonScriptStep

source_directory = 'Scripts'
model_name = 'OJForecastingModel'
model_description = 'Built using AutoML'
#registeredModelInput = InputPortBinding("bestmodel", bind_object=model_data_bestmodel)

pyscriptStepRegisterModel = PythonScriptStep(name="pystepRegisterModel",
                                             script_name="registermodel.py",
                                             arguments=["--model_path", model_data_bestmodel, 
                                                        "--model_name", model_name, 
                                                        "--model_description",model_description],
                                             inputs=[model_data_bestmodel],
                                             compute_target=compute_target, 
                                             source_directory=source_directory,
                                             allow_reuse=False)

print("pyscriptStepRegisterModel Script Step Created")
# Out:
# pyscriptStepRegisterModel Script Step Created

# %%
from azureml.pipeline.core import Pipeline

amlpipeline = Pipeline(workspace=mlonazure_ws, 
         steps=[automl_step,pyscriptStepRegisterModel],
         description= 'ForecastOJSales Training Pipeline! July 2020')

# %%
from azureml.core import Experiment 

experiment_name = 'OJ_Sales_Quantity_Prediction_Pipeline'
experiment = Experiment(workspace = mlonazure_ws, name = experiment_name)

experiment.tag('Author', 'mlonazure')
experiment.tag('Department', 'Finance')
experiment.tag('Executor', 'Manual')

exp_pipelinerun = experiment.submit(amlpipeline)

exp_pipelinerun.wait_for_completion()

# %%
amlpipeline.publish(
        name='OJSalesTrainingPipeline July', 
        description='AML Pipeline for automation July', 
        version=None, 
        continue_on_step_failure=False)
# Out:
# Created step TrainOJSalesData_AutoML [1d646e61][3098c279-c519-4169-8148-940ac500ddd5], (This step will run and generate new outputs)
# Created step pystepRegisterModel [b81edef3][31dbdf24-c178-4c64-ac52-5c98be8a6d02], (This step will run and generate new outputs)
# Pipeline(Name: OJSalesTrainingPipeline July,
# Id: 77726f6d-b73e-43a9-9540-a5a5511c51ff,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe/resourceGroups/mlonazure-rg/providers/Microsoft.MachineLearningServices/workspaces/mlonazure-ws/PipelineRuns/PipelineSubmit/77726f6d-b73e-43a9-9540-a5a5511c51ff)

# %%
from azureml.pipeline.core import PipelineEndpoint

pipelineEndPoint = PipelineEndpoint.publish(workspace=mlonazure_ws, name="OJSales Prediction EndPoint",
                                            pipeline=amlpipeline, description="Pipeline EndPoint for OJSales Prediction")
pipelineEndPoint

#Note that once you have published a pipeline, you can add other pipelines to it using, pipelineEndPoint.add(publishedPipeline)
# Out:
# PipelineEndpoint(Name: OJSales Prediction EndPoint,
# Id: e54c2487-cd98-4aff-807e-c952d7280368,
# Description: Pipeline EndPoint for OJSales Prediction,
# Pipelines: [('0', Pipeline(Name: OJSales Prediction EndPoint-07-09-2020-13-16-Pipeline,
# Id: 6ab9eb5b-ac3b-4df8-9149-244663e184a6,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe/resourceGroups/mlonazure-rg/providers/Microsoft.MachineLearningServices/workspaces/mlonazure-ws/PipelineRuns/PipelineSubmit/6ab9eb5b-ac3b-4df8-9149-244663e184a6))])

# %%
from azureml.core import Experiment 

experiment_name = 'OJ_Sales_Quantity_Prediction_Pipeline'
experiment = Experiment(workspace = mlonazure_ws, name = experiment_name)

experiment.tag('Author', 'mlonazure')
experiment.tag('Department', 'Finance')
experiment.tag('Executor', 'Manual with EndPoint')

exp_pipelinerun = experiment.submit(pipelineEndPoint)

exp_pipelinerun.wait_for_completion()
# Out:
# PipelineRunId: 99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/OJ_Sales_Quantity_Prediction_Pipeline/runs/99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f?wsid=/subscriptions/286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe/resourcegroups/mlonazure-rg/workspaces/mlonazure-ws
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 89e8bdb9-2b57-44a9-a620-134b0c81ec2c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/OJ_Sales_Quantity_Prediction_Pipeline/runs/89e8bdb9-2b57-44a9-a620-134b0c81ec2c?wsid=/subscriptions/286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe/resourcegroups/mlonazure-rg/workspaces/mlonazure-ws
# StepRun( TrainOJSalesData_AutoML ) Status: NotStarted
# StepRun( TrainOJSalesData_AutoML ) Status: Running
#
# StepRun(TrainOJSalesData_AutoML) Execution Summary
# ===================================================
# StepRun( TrainOJSalesData_AutoML ) Status: Finished
# {'runId': '89e8bdb9-2b57-44a9-a620-134b0c81ec2c', 'target': 'amlcluster2c-4gb', 'status': 'Completed', 'startTimeUtc': '2020-07-09T13:41:03.29925Z', 'endTimeUtc': '2020-07-09T13:53:17.239895Z', 'properties': {'azureml.git.repository_uri': 'https://github.com/mlonazure/AzureMachineLearning.git', 'mlflow.source.git.repoURL': 'https://github.com/mlonazure/AzureMachineLearning.git', 'azureml.git.branch': 'master', 'mlflow.source.git.branch': 'master', 'azureml.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'mlflow.source.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'azureml.git.dirty': 'True', 'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '3b9fbd93-9795-408f-bbc4-641cd0e82949', 'StepType': 'AutoMLStep', 'azureml.moduleid': '3098c279-c519-4169-8148-940ac500ddd5', 'azureml.pipelinerunid': '99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f', 'azureml.pipelineid': '6ab9eb5b-ac3b-4df8-9149-244663e184a6', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'r2_score', 'train_split': '0', 'MaxTimeSeconds': '7200', 'acquisition_parameter': '0', 'num_cross_validation': '3', 'target': 'amlcluster2c-4gb', 'RawAMLSettingsString': "{'name': 'placeholder', 'path': './project', 'subscription_id': '286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe', 'resource_group': 'mlonazure-rg', 'workspace_name': 'mlonazure-ws', 'region': 'eastus2', 'compute_target': None, 'spark_service': None, 'azure_service': None, '_local_managed_run_id': None, 'iterations': 1000, 'primary_metric': 'r2_score', 'task_type': 'regression', 'data_script': None, 'validation_size': 0.0, 'n_cross_validations': 3, 'y_min': None, 'y_max': None, 'num_classes': None, 'featurization': 'auto', '_ignore_package_version_incompatibilities': False, 'is_timeseries': True, 'max_cores_per_iteration': -1, 'max_concurrent_iterations': 20, 'iteration_timeout_minutes': 120, 'mem_in_mb': None, 'enforce_time_on_windows': False, 'experiment_timeout_minutes': 600, 'experiment_exit_score': None, 'whitelist_models': None, 'blacklist_algos': None, 'supported_models': ['TCNForecaster', 'DecisionTree', 'FastLinearRegressor', 'LightGBM', 'KNN', 'SGD', 'XGBoostRegressor', 'TensorFlowLinearRegressor', 'AutoArima', 'GradientBoosting', 'ElasticNet', 'ExtremeRandomTrees', 'Prophet', 'LassoLars', 'OnlineGradientDescentRegressor', 'RandomForest', 'TensorFlowDNN'], 'auto_blacklist': True, 'blacklist_samples_reached': False, 'exclude_nan_labels': True, 'verbosity': 20, '_debug_log': 'automl_debuglog.log', 'show_warnings': False, 'model_explainability': True, 'service_url': None, 'sdk_url': None, 'sdk_packages': None, 'enable_onnx_compatible_models': False, 'enable_split_onnx_featurizer_estimator_models': False, 'vm_type': 'STANDARD_F4S_V2', 'telemetry_verbosity': 20, 'send_telemetry': True, 'enable_dnn': False, 'force_text_dnn': False, 'enable_feature_sweeping': False, 'time_column_name': 'WeekStarting', 'grain_column_names': ['Store', 'Brand'], 'drop_column_names': [], 'max_horizon': 6, 'dropna': False, 'overwrite_columns': True, 'transform_dictionary': {'min': '_automl_target_col', 'max': '_automl_target_col', 'mean': '_automl_target_col'}, 'window_size': None, 'country_or_region': None, 'lags': None, 'feature_lags': None, 'seasonality': -1, 'use_stl': None, 'short_series_handling': True, 'enable_early_stopping': True, 'early_stopping_n_iters': 10, 'metrics': None, 'enable_ensembling': True, 'enable_stack_ensembling': False, 'ensemble_iterations': 15, 'enable_tf': False, 'enable_cache': True, 'enable_subsampling': False, 'subsample_seed': None, 'enable_nimbusml': False, 'enable_streaming': False, 'force_streaming': False, 'track_child_runs': True, 'label_column_name': 'Quantity', 'weight_column_name': None, 'cv_split_column_names': None, 'enable_local_managed': False, 'cost_mode': 1, 'lag_length': 0, 'metric_operation': 'maximize', 'preprocess': True, 'scenario': 'SDK-Compatible'}", 'AMLSettingsJsonString': '{"name": "placehold ...
#
#
#
#
# StepRunId: 5687d796-56b7-4b24-ab95-b621b57190ab
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/OJ_Sales_Quantity_Prediction_Pipeline/runs/5687d796-56b7-4b24-ab95-b621b57190ab?wsid=/subscriptions/286d2a8f-e90b-4e3f-b4d7-08971a2ab3fe/resourcegroups/mlonazure-rg/workspaces/mlonazure-ws
# StepRun( pystepRegisterModel ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/07/09 14:03:25 Downloading source code...
# 2020/07/09 14:03:26 Finished downloading source code
# 2020/07/09 14:03:27 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/07/09 14:03:27 Successfully set up Docker network: acb_default_network
# 2020/07/09 14:03:27 Setting up Docker configuration...
# 2020/07/09 14:03:28 Successfully set up Docker configuration
# 2020/07/09 14:03:28 Logging in to registry: mlonazurews414b2150.azurecr.io
# 2020/07/09 14:03:29 Successfully logged into mlonazurews414b2150.azurecr.io
# 2020/07/09 14:03:29 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/09 14:03:29 Scanning for dependencies...
# 2020/07/09 14:03:30 Successfully scanned dependencies
# 2020/07/09 14:03:30 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 57db7fe0b522: Waiting
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# StepRun( pystepRegisterModel ) Status: Running
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/15 : USER root
#  ---> Running in 13e6d5a00b56
# Removing intermediate container 13e6d5a00b56
#  ---> 2efb7486b23d
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 6cf5fbe7b3a4
# Removing intermediate container 6cf5fbe7b3a4
#  ---> 51b87a2f3ed5
# Step 4/15 : WORKDIR /
#  ---> Running in 52820de0ef11
# Removing intermediate container 52820de0ef11
#  ---> 693a4a016423
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> de420a1a9aab
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in e7b1de84e090
# Removing intermediate container e7b1de84e090
#  ---> 727143de7210
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 1f45a0d3aa69
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in d7ae01451962
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######5   |  76%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# pip-20.1.1           | 2.0 MB    |            |   0%
# pip-20.1.1           | 2.0 MB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #9         |  20%
# python-3.6.2         | 27.0 MB   | #####3     |  54%
# python-3.6.2         | 27.0 MB   | ########7  |  88%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ###2       |  33%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# setuptools-47.3.1    | 647 KB    |            |   0%
# setuptools-47.3.1    | 647 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.6f25vw2z.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.9.0-py3-none-any.whl (3.0 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataprep[fuse]<1.10.0a,>=1.9.0a
#   Downloading azureml_dataprep-1.9.1-py3-none-any.whl (27.7 MB)
# Collecting azureml-core~=1.9.0
#   Downloading azureml_core-1.9.0-py3-none-any.whl (1.5 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.2.1
#   Downloading azureml_dataprep_native-14.2.1-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.1.0-py2.py3-none-any.whl (892 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting docker
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.17-py2.py3-none-any.whl (84 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting numpy>=1.13.0
#   Downloading numpy-1.19.0-cp36-cp36m-manylinux2010_x86_64.whl (14.6 MB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.0.5-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting six>=1.10
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.7.0-py2.py3-none-any.whl (121 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.1-py2.py3-none-any.whl (48 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.9.0->azureml-defaults->-r /azureml-environment-setup/condaenv.6f25vw2z.requirements.txt (line 1)) (2020.6.20)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff, dill
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=3a1c399e858a441db6f0a46b51c6974689698038b45a89b7c754cb9326221561
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=293e0287767a1c89dce3b8b30f0a93a6fb1468d083a01e80203d5d1ac11820d6
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=f086a91d44c3aac8b493146ca0b8303fb2d33c46f76d981d64e689356581c311
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=db13588cf7262f86640de849bf86c781b5acf47fa3f88d9dc6a35607029ba5cc
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
# Successfully built json-logging-py fusepy liac-arff dill
# Installing collected packages: configparser, distro, dotnetcore2, cloudpickle, azureml-dataprep-native, pycparser, cffi, six, cryptography, idna, urllib3, chardet, requests, azure-core, PyJWT, msal, portalocker, msal-extensions, azure-identity, fusepy, azureml-dataprep, python-dateutil, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-graphrbac, jeepney, SecretStorage, pyopenssl, jmespath, backports.weakref, backports.tempfile, azure-mgmt-storage, pyasn1, ndg-httpsclient, azure-mgmt-keyvault, azure-mgmt-resource, azure-mgmt-network, azure-mgmt-authorization, contextlib2, websocket-client, docker, azure-mgmt-containerregistry, pytz, ruamel.yaml.clib, ruamel.yaml, pathspec, zipp, importlib-metadata, jsonpickle, azureml-core, json-logging-py, gunicorn, applicationinsights, liac-arff, dill, numpy, pandas, azureml-model-management-sdk, werkzeug, itsdangerous, MarkupSafe, Jinja2, click, flask, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.7.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.1.0 azure-mgmt-storage-11.1.0 azureml-core-1.9.0 azureml-dataprep-1.9.1 azureml-dataprep-native-14.2.1 azureml-defaults-1.9.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 click-7.1.2 cloudpickle-1.5.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.9.2 dill-0.3.2 distro-1.5.0 docker-4.2.2 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.4.1 msal-extensions-0.1.3 msrest-0.6.17 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.19.0 oauthlib-3.1.0 pandas-1.0.5 pathspec-0.8.0 portalocker-1.7.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 six-1.15.0 urllib3-1.25.9 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container d7ae01451962
#  ---> 7092684a6abf
# Step 9/15 : ENV PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/bin:$PATH
#  ---> Running in 751d4d741a7e
# Removing intermediate container 751d4d741a7e
#  ---> 6b61c08ca739
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad
#  ---> Running in f2551b7f8ec7
# Removing intermediate container f2551b7f8ec7
#  ---> e90192649cab
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_da3e97fcb51801118b8e80207f3e01ad/lib:$LD_LIBRARY_PATH
#  ---> Running in 46dbd3c457c9
# Removing intermediate container 46dbd3c457c9
#  ---> c10982f086ae
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 0b9a104d1425
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in a92359f6096e
# Removing intermediate container a92359f6096e
#  ---> ef80d622d824
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 13d2eecd5798
# Removing intermediate container 13d2eecd5798
#  ---> c1dee01a636b
# Step 15/15 : CMD ["bash"]
#  ---> Running in 0751bfdd8860
# Removing intermediate container 0751bfdd8860
#  ---> a71006216d00
# Successfully built a71006216d00
# Successfully tagged mlonazurews414b2150.azurecr.io/azureml/azureml_4937d92dbbd4ab7313202414973a219d:latest
# 2020/07/09 14:06:07 Successfully executed container: acb_step_0
# 2020/07/09 14:06:07 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/07/09 14:06:07 Pushing image: mlonazurews414b2150.azurecr.io/azureml/azureml_4937d92dbbd4ab7313202414973a219d:latest, attempt 1
# The push refers to repository [mlonazurews414b2150.azurecr.io/azureml/azureml_4937d92dbbd4ab7313202414973a219d]
# c60ea1b1267d: Preparing
# a0a21fdcef86: Preparing
# 90538e18eaec: Preparing
# 8532bfdc7914: Preparing
# 0d175b94fbac: Preparing
# 6544c0a50ef2: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 7e2b9752143f: Waiting
# 6544c0a50ef2: Waiting
# f5aa53607bc1: Waiting
# 63a67842a4c7: Waiting
# ae3a847dbd6b: Waiting
# 07eae5ad8c0b: Waiting
# 4ae3adcb66cb: Waiting
# facf43cddd83: Waiting
# aa6685385151: Waiting
# 69a9bdc813b0: Waiting
# 0040d8f00d7e: Waiting
# 9e6f810a2aab: Waiting
# 0d175b94fbac: Pushed
# 90538e18eaec: Pushed
# c60ea1b1267d: Pushed
# 8532bfdc7914: Pushed
# 6544c0a50ef2: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
# 63a67842a4c7: Pushed
# facf43cddd83: Pushed
# 4ae3adcb66cb: Pushed
# aa6685385151: Pushed
# 7e2b9752143f: Pushed
# 69a9bdc813b0: Pushed
# 0040d8f00d7e: Pushed
# ae3a847dbd6b: Pushed
# 9e6f810a2aab: Pushed
# a0a21fdcef86: Pushed
# latest: digest: sha256:5d7f15e6877458170270f6e6123d0472a031e1d20cdf90b3ad32ac8e88dbeb1b size: 3883
# 2020/07/09 14:07:25 Successfully pushed image: mlonazurews414b2150.azurecr.io/azureml/azureml_4937d92dbbd4ab7313202414973a219d:latest
# 2020/07/09 14:07:25 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 157.856021)
# 2020/07/09 14:07:25 Populating digests for step ID: acb_step_0...
# 2020/07/09 14:07:26 Successfully populated digests for step ID: acb_step_0
# 2020/07/09 14:07:26 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 78.289518)
# 2020/07/09 14:07:26 The following dependencies were found:
# 2020/07/09 14:07:26
# - image:
#     registry: mlonazurews414b2150.azurecr.io
#     repository: azureml/azureml_4937d92dbbd4ab7313202414973a219d
#     tag: latest
#     digest: sha256:5d7f15e6877458170270f6e6123d0472a031e1d20cdf90b3ad32ac8e88dbeb1b
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
# Run ID: chp was successful after 4m2s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_fe8ff390d47eb9b1ec9e3d15b187601f43fa797eaa11ba644f078dce44444042_d.txt
# ========================================================================================================================
# 2020-07-09T14:08:19Z Starting output-watcher...
# 2020-07-09T14:08:20Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
#
# Streaming azureml-logs/65_job_prep-tvmps_fe8ff390d47eb9b1ec9e3d15b187601f43fa797eaa11ba644f078dce44444042_d.txt
# ===============================================================================================================
# [2020-07-09T14:08:38.929262] Entering job preparation.
# [2020-07-09T14:08:39.799851] Starting job preparation.
# [2020-07-09T14:08:39.799884] Extracting the control code.
# [2020-07-09T14:08:39.852786] fetching and extracting the control code on master node.
# [2020-07-09T14:08:41.175761] Retrieving project from snapshot: ebf6c9f6-d654-4eaf-b952-a0d1def93527
# Starting the daemon thread to refresh tokens in background for process with pid = 59
# [2020-07-09T14:08:41.176681] Start RetrieveProjectSasUrls
# [2020-07-09T14:08:41.556930] Finished RetrieveProjectSasUrls
# [2020-07-09T14:08:41.558210] Starting project file download.
# [2020-07-09T14:08:41.925191] Finished project file download.
# [2020-07-09T14:08:41.979889] Finished fetching and extracting the control code.
# [2020-07-09T14:08:41.982584] downloadDataStore - Download from datastores if requested.
# [2020-07-09T14:08:41.983782] Start run_history_prep.
# [2020-07-09T14:08:42.151984] Entering context manager injector.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-07-09T14:08:45.183978] Entering context manager injector.
# Starting the daemon thread to refresh tokens in background for process with pid = 121
#
# Streaming azureml-logs/75_job_post-tvmps_fe8ff390d47eb9b1ec9e3d15b187601f43fa797eaa11ba644f078dce44444042_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-07-09T14:08:52.705535
# Starting job release. Current time:2020-07-09T14:08:53.592658
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 160
# [2020-07-09T14:08:53.611522] Entering context manager injector.
# Job release is complete. Current time:2020-07-09T14:08:55.533215
#
# StepRun(pystepRegisterModel) Execution Summary
# ===============================================
# StepRun( pystepRegisterModel ) Status: Finished
# {'runId': '5687d796-56b7-4b24-ab95-b621b57190ab', 'target': 'amlcluster2c-4gb', 'status': 'Completed', 'startTimeUtc': '2020-07-09T14:07:49.54282Z', 'endTimeUtc': '2020-07-09T14:08:59.836829Z', 'properties': {'azureml.git.repository_uri': 'https://github.com/mlonazure/AzureMachineLearning.git', 'mlflow.source.git.repoURL': 'https://github.com/mlonazure/AzureMachineLearning.git', 'azureml.git.branch': 'master', 'mlflow.source.git.branch': 'master', 'azureml.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'mlflow.source.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'azureml.git.dirty': 'True', 'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'ebf6c9f6-d654-4eaf-b952-a0d1def93527', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '31dbdf24-c178-4c64-ac52-5c98be8a6d02', 'azureml.pipelinerunid': '99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f', 'azureml.pipelineid': '6ab9eb5b-ac3b-4df8-9149-244663e184a6', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'registermodel.py', 'useAbsolutePath': False, 'arguments': ['--model_path', '$AZUREML_DATAREFERENCE_model_data_bestmodel', '--model_name', 'OJForecastingModel', '--model_description', 'Built using AutoML'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'amlcluster2c-4gb', 'dataReferences': {'model_data_bestmodel': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/89e8bdb9-2b57-44a9-a620-134b0c81ec2c/model_data_bestmodel', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment OJ_Sales_Quantity_Prediction_Pipeline Environment', 'version': 'Autosave_2020-07-09T14:03:22Z_d70e6aac', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}], 'name': 'azureml_da3e97fcb51801118b8e80207f3e01ad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlonazurews7669880942.blob.core.windows.net/azureml/ExperimentRun/dcid.5687d796-56b7-4b24-ab95-b621b57190ab/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=YLyjD2qAQ8GAhYWh7pLttULEpsB9k2eTLh%2F3FdjJbZU%3D&st=2020-07-09T13%3A59%3A02Z&se=2020-07-09T22%3A09%3A02Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_fe8ff390d47eb9b1ec9e3d15b187601f43fa797eaa11ba644f078dce44444042_d.txt': 'https://mlonazurews766988 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f', 'status': 'Completed', 'startTimeUtc': '2020-07-09T13:17:51.658149Z', 'endTimeUtc': '2020-07-09T14:09:00.589939Z', 'properties': {'azureml.git.repository_uri': 'https://github.com/mlonazure/AzureMachineLearning.git', 'mlflow.source.git.repoURL': 'https://github.com/mlonazure/AzureMachineLearning.git', 'azureml.git.branch': 'master', 'mlflow.source.git.branch': 'master', 'azureml.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'mlflow.source.git.commit': '02fb4772a355b305e0d007736430b6e0bcfc78ca', 'azureml.git.dirty': 'True', 'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.pipelineid': '6ab9eb5b-ac3b-4df8-9149-244663e184a6'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlonazurews7669880942.blob.core.windows.net/azureml/ExperimentRun/dcid.99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=NAYg4jZ3uRCGuN45MtIQVjc1L3YmgIIZZ%2F7eHTkrVCs%3D&st=2020-07-09T13%3A59%3A04Z&se=2020-07-09T22%3A09%3A04Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlonazurews7669880942.blob.core.windows.net/azureml/ExperimentRun/dcid.99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=SrSOQRjzmT9vR5jnPlWf0wzaq%2BJH7GQ2vKF%2FF%2FhdZ8k%3D&st=2020-07-09T13%3A59%3A04Z&se=2020-07-09T22%3A09%3A04Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlonazurews7669880942.blob.core.windows.net/azureml/ExperimentRun/dcid.99ec2d4f-681a-4e4b-bbd5-89aa0d5b1e8f/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=H4UsAJzsqGUYT6eZmqIYu9lKgO%2BH73ubgpcZ%2BvtdL2E%3D&st=2020-07-09T13%3A59%3A04Z&se=2020-07-09T22%3A09%3A04Z&sp=r'}}
# 'Finished'
